# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/ugcqz6ohbvff804xp84y4kqnvvk3bq1g.png" width = 300, align = "center"></a>
#
# <h1 align=center><font size = 5>Lab: Working with a real world data-set using SQL and Python</font></h1>

# %% [markdown]
# # Introduction
#
# This notebook shows how to work with a real world dataset using SQL and Python. In this lab you will:
# 1. Understand the dataset for Chicago Public School level performance
# 1. Store the dataset in an Db2 database on IBM Cloud instance
# 1. Retrieve metadata about tables and columns and query data from mixed case columns
# 1. Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true
#
# __NOTE__: Do not download the dataset directly from City of Chicago portal. Instead download a more database friendly version from the link below.
# Now download a static copy of this database and review some of its contents:
# https://ibm.box.com/shared/static/f9gjvj1gjmxxzycdhplzt01qtz0s7ew7.csv

# %% [markdown]
# ### Store the dataset in a Table
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in the previous lab, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, __it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II__. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the CHICAGO PUBLIC SCHOOLS dataset and load the dataset into a new table called __SCHOOLS__.
#
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/uc4xjh1uxcc78ks1i18v668simioz4es.jpg"></a>

# %% [markdown]
# ### Connect to the database
# Let us now load the ipython-sql  extension and establish a connection with the database

# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# %sql ibm_db_sa://dash101176:jTkBiN_4j_Y7@dashdb-entry-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB;
# Out:
# 'Connected: dash101176@BLUDB;'

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
      where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
# Out:
#  * ibm_db_sa://dash101176:***@dashdb-entry-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB;
# Done.
# [('GOSALES ', 'BRANCH', datetime.datetime(2016, 6, 29, 23, 47, 15, 811463)),
#  ('GOSALES ', 'CONVERSION_RATE', datetime.datetime(2016, 6, 29, 23, 47, 15, 960513)),
#  ('GOSALES ', 'COUNTRY', datetime.datetime(2016, 6, 29, 23, 47, 16, 41288)),
#  ('GOSALES ', 'CURRENCY_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 16, 136414)),
#  ('GOSALES ', 'EURO_CONVERSION', datetime.datetime(2016, 6, 29, 23, 47, 16, 224752)),
#  ('GOSALES ', 'INVENTORY_LEVELS', datetime.datetime(2016, 6, 29, 23, 47, 16, 305532)),
#  ('GOSALES ', 'ORDER_DETAILS', datetime.datetime(2016, 6, 29, 23, 47, 16, 389560)),
#  ('GOSALES ', 'ORDER_HEADER', datetime.datetime(2016, 6, 29, 23, 47, 16, 471526)),
#  ('GOSALES ', 'ORDER_METHOD', datetime.datetime(2016, 6, 29, 23, 47, 16, 554568)),
#  ('GOSALES ', 'PRODUCT', datetime.datetime(2016, 6, 29, 23, 47, 16, 643366)),
#  ('GOSALES ', 'PRODUCT_BRAND', datetime.datetime(2016, 6, 29, 23, 47, 16, 723829)),
#  ('GOSALES ', 'PRODUCT_COLOR_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 16, 812406)),
#  ('GOSALES ', 'PRODUCT_FORECAST', datetime.datetime(2016, 6, 29, 23, 47, 16, 900099)),
#  ('GOSALES ', 'PRODUCT_LINE', datetime.datetime(2016, 6, 29, 23, 47, 16, 981730)),
#  ('GOSALES ', 'PRODUCT_NAME_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 17, 70557)),
#  ('GOSALES ', 'PRODUCT_SIZE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 17, 151099)),
#  ('GOSALES ', 'PRODUCT_TYPE', datetime.datetime(2016, 6, 29, 23, 47, 17, 238754)),
#  ('GOSALES ', 'RETURNED_ITEM', datetime.datetime(2016, 6, 29, 23, 47, 17, 328287)),
#  ('GOSALES ', 'RETURN_REASON', datetime.datetime(2016, 6, 29, 23, 47, 17, 409566)),
#  ('GOSALES ', 'SALES_REGION', datetime.datetime(2016, 6, 29, 23, 47, 17, 496569)),
#  ('GOSALES ', 'SALES_TARGET', datetime.datetime(2016, 6, 29, 23, 47, 17, 583789)),
#  ('GOSALES ', 'TIME_DIMENSION', datetime.datetime(2016, 6, 29, 23, 47, 17, 666270)),
#  ('GOSALES ', 'TIME_QUARTER_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 17, 771440)),
#  ('GOSALES ', 'XGOREV', datetime.datetime(2016, 6, 29, 23, 47, 17, 858318)),
#  ('GOSALESHR', 'DEPARTMENT_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 17, 970044)),
#  ('GOSALESHR', 'EMPLOYEE', datetime.datetime(2016, 6, 29, 23, 47, 18, 60288)),
#  ('GOSALESHR', 'EMPLOYEE_EXPENSE_DETAIL', datetime.datetime(2016, 6, 29, 23, 47, 18, 143018)),
#  ('GOSALESHR', 'EMPLOYEE_EXPENSE_PLAN', datetime.datetime(2016, 6, 29, 23, 47, 18, 220005)),
#  ('GOSALESHR', 'EMPLOYEE_HISTORY', datetime.datetime(2016, 6, 29, 23, 47, 18, 300015)),
#  ('GOSALESHR', 'EMPLOYEE_SUMMARY', datetime.datetime(2016, 6, 29, 23, 47, 18, 383919)),
#  ('GOSALESHR', 'EMPLOYEE_SURVEY_RESULTS', datetime.datetime(2016, 6, 29, 23, 47, 18, 463532)),
#  ('GOSALESHR', 'EMPLOYEE_SURVEY_TARGETS', datetime.datetime(2016, 6, 29, 23, 47, 18, 541011)),
#  ('GOSALESHR', 'EMPLOYEE_SURVEY_TOPIC', datetime.datetime(2016, 6, 29, 23, 47, 18, 618780)),
#  ('GOSALESHR', 'EXPENSE_GROUP', datetime.datetime(2016, 6, 29, 23, 47, 18, 701712)),
#  ('GOSALESHR', 'EXPENSE_TYPE', datetime.datetime(2016, 6, 29, 23, 47, 18, 783189)),
#  ('GOSALESHR', 'EXPENSE_UNIT', datetime.datetime(2016, 6, 29, 23, 47, 18, 865380)),
#  ('GOSALESHR', 'GENDER_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 18, 946164)),
#  ('GOSALESHR', 'ORGANIZATION', datetime.datetime(2016, 6, 29, 23, 47, 19, 26074)),
#  ('GOSALESHR', 'POSITION_DEPARTMENT', datetime.datetime(2016, 6, 29, 23, 47, 19, 107816)),
#  ('GOSALESHR', 'POSITION_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 19, 179547)),
#  ('GOSALESHR', 'POSITION_SUMMARY', datetime.datetime(2016, 6, 29, 23, 47, 19, 313042)),
#  ('GOSALESHR', 'RANKING', datetime.datetime(2016, 6, 29, 23, 47, 19, 390810)),
#  ('GOSALESHR', 'RANKING_RESULTS', datetime.datetime(2016, 6, 29, 23, 47, 19, 472643)),
#  ('GOSALESHR', 'RECRUITMENT', datetime.datetime(2016, 6, 29, 23, 47, 19, 544561)),
#  ('GOSALESHR', 'RECRUITMENT_MEDIUM', datetime.datetime(2016, 6, 29, 23, 47, 19, 618916)),
#  ('GOSALESHR', 'RECRUITMENT_TYPE', datetime.datetime(2016, 6, 29, 23, 47, 19, 702752)),
#  ('GOSALESHR', 'SATISFACTION_INDEX', datetime.datetime(2016, 6, 29, 23, 47, 19, 786470)),
#  ('GOSALESHR', 'SUCCESSION_DETAILS', datetime.datetime(2016, 6, 29, 23, 47, 19, 874069)),
#  ('GOSALESHR', 'SUCCESSOR_STATUS', datetime.datetime(2016, 6, 29, 23, 47, 19, 964655)),
#  ('GOSALESHR', 'TERMINATION_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 20, 51866)),
#  ('GOSALESHR', 'TRAINING', datetime.datetime(2016, 6, 29, 23, 47, 20, 134964)),
#  ('GOSALESHR', 'TRAINING_DETAILS', datetime.datetime(2016, 6, 29, 23, 47, 20, 220256)),
#  ('GOSALESMR', 'PRODUCT_SURVEY_RESULTS', datetime.datetime(2016, 6, 29, 23, 47, 20, 325685)),
#  ('GOSALESMR', 'PRODUCT_SURVEY_TARGETS', datetime.datetime(2016, 6, 29, 23, 47, 20, 400919)),
#  ('GOSALESMR', 'PRODUCT_SURVEY_TOPIC', datetime.datetime(2016, 6, 29, 23, 47, 20, 477226)),
#  ('GOSALESMR', 'PROMOTIONS', datetime.datetime(2016, 6, 29, 23, 47, 20, 561161)),
#  ('GOSALESMR', 'PROMOTION_BUNDLE_GROUP', datetime.datetime(2016, 6, 29, 23, 47, 20, 645058)),
#  ('GOSALESMR', 'PROMOTION_CAMPAIGN', datetime.datetime(2016, 6, 29, 23, 47, 20, 727365)),
#  ('GOSALESMR', 'PROMOTION_PLAN', datetime.datetime(2016, 6, 29, 23, 47, 20, 808808)),
#  ('GOSALESMR', 'RETAILER_SURVEY_RESULTS', datetime.datetime(2016, 6, 29, 23, 47, 20, 890243)),
#  ('GOSALESMR', 'RETAILER_SURVEY_TARGETS', datetime.datetime(2016, 6, 29, 23, 47, 20, 964979)),
#  ('GOSALESMR', 'RETAILER_SURVEY_TOPIC', datetime.datetime(2016, 6, 29, 23, 47, 21, 38371)),
#  ('GOSALESRT', 'ACTIVITY_STATUS_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 21, 147356)),
#  ('GOSALESRT', 'RETAILER', datetime.datetime(2016, 6, 29, 23, 47, 21, 216217)),
#  ('GOSALESRT', 'RETAILER_ACTIVITY', datetime.datetime(2016, 6, 29, 23, 47, 21, 285941)),
#  ('GOSALESRT', 'RETAILER_CONTACT', datetime.datetime(2016, 6, 29, 23, 47, 21, 357434)),
#  ('GOSALESRT', 'RETAILER_SITE', datetime.datetime(2016, 6, 29, 23, 47, 21, 440375)),
#  ('GOSALESRT', 'RETAILER_SITE_MB', datetime.datetime(2016, 6, 29, 23, 47, 21, 513719)),
#  ('GOSALESRT', 'RETAILER_TYPE', datetime.datetime(2016, 6, 29, 23, 47, 21, 585430)),
#  ('GOSALESDW', 'AGGR_TIME_PROD_OM_FACT', datetime.datetime(2016, 6, 29, 23, 47, 21, 694022)),
#  ('GOSALESDW', 'BURST_TABLE', datetime.datetime(2016, 6, 29, 23, 47, 21, 801259)),
#  ('GOSALESDW', 'BURST_TABLE2', datetime.datetime(2016, 6, 29, 23, 47, 21, 875197)),
#  ('GOSALESDW', 'DIST_INVENTORY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 21, 950633)),
#  ('GOSALESDW', 'DIST_PRODUCT_FORECAST_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 23783)),
#  ('GOSALESDW', 'DIST_RETURNED_ITEMS_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 96128)),
#  ('GOSALESDW', 'DIST_RETURN_REASON_DIM', datetime.datetime(2016, 6, 29, 23, 47, 22, 170972)),
#  ('GOSALESDW', 'EMP_EMPLOYEE_DIM', datetime.datetime(2016, 6, 29, 23, 47, 22, 252661)),
#  ('GOSALESDW', 'EMP_EXPENSE_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 341263)),
#  ('GOSALESDW', 'EMP_EXPENSE_PLAN_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 415607)),
#  ('GOSALESDW', 'EMP_EXPENSE_TYPE_DIM', datetime.datetime(2016, 6, 29, 23, 47, 22, 490805)),
#  ('GOSALESDW', 'EMP_EXPENSE_UNIT_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 22, 588235)),
#  ('GOSALESDW', 'EMP_POSITION_DIM', datetime.datetime(2016, 6, 29, 23, 47, 22, 670032)),
#  ('GOSALESDW', 'EMP_POSITION_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 22, 743845)),
#  ('GOSALESDW', 'EMP_POSITION_SUMMARY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 825268)),
#  ('GOSALESDW', 'EMP_RANKING_DIM', datetime.datetime(2016, 6, 29, 23, 47, 22, 897238)),
#  ('GOSALESDW', 'EMP_RANKING_FACT', datetime.datetime(2016, 6, 29, 23, 47, 22, 977478)),
#  ('GOSALESDW', 'EMP_RECRUITMENT_DIM', datetime.datetime(2016, 6, 29, 23, 47, 23, 50372)),
#  ('GOSALESDW', 'EMP_RECRUITMENT_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 140424)),
#  ('GOSALESDW', 'EMP_RECRUITMENT_LEAD_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 212024)),
#  ('GOSALESDW', 'EMP_SUCCESSION_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 283968)),
#  ('GOSALESDW', 'EMP_SUCCESSION_STATUS_DIM', datetime.datetime(2016, 6, 29, 23, 47, 23, 356105)),
#  ('GOSALESDW', 'EMP_SUMMARY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 427290)),
#  ('GOSALESDW', 'EMP_SURVEY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 499282)),
#  ('GOSALESDW', 'EMP_SURVEY_TARG_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 569997)),
#  ('GOSALESDW', 'EMP_SURVEY_TOPIC_DIM', datetime.datetime(2016, 6, 29, 23, 47, 23, 642015)),
#  ('GOSALESDW', 'EMP_TERMINATION_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 23, 724069)),
#  ('GOSALESDW', 'EMP_TRAINING_DIM', datetime.datetime(2016, 6, 29, 23, 47, 23, 814079)),
#  ('GOSALESDW', 'EMP_TRAINING_FACT', datetime.datetime(2016, 6, 29, 23, 47, 23, 888884)),
#  ('GOSALESDW', 'FIN_ACCOUNT_CLASS_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 23, 964929)),
#  ('GOSALESDW', 'FIN_ACCOUNT_DIM', datetime.datetime(2016, 6, 29, 23, 47, 24, 64455)),
#  ('GOSALESDW', 'FIN_ACCOUNT_NAME_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 155532)),
#  ('GOSALESDW', 'FIN_ACCOUNT_TYPE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 242269)),
#  ('GOSALESDW', 'FIN_FINANCE_FACT', datetime.datetime(2016, 6, 29, 23, 47, 24, 334131)),
#  ('GOSALESDW', 'FIN_SUBM_CURRENCY_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 417939)),
#  ('GOSALESDW', 'FIN_SUBM_DIM', datetime.datetime(2016, 6, 29, 23, 47, 24, 505283)),
#  ('GOSALESDW', 'FIN_SUBM_TYPE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 590370)),
#  ('GOSALESDW', 'GO_BRANCH_DIM', datetime.datetime(2016, 6, 29, 23, 47, 24, 673154)),
#  ('GOSALESDW', 'GO_GENDER_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 748487)),
#  ('GOSALESDW', 'GO_ORG_DIM', datetime.datetime(2016, 6, 29, 23, 47, 24, 830115)),
#  ('GOSALESDW', 'GO_ORG_NAME_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 24, 906221)),
#  ('GOSALESDW', 'GO_REGION_DIM', datetime.datetime(2016, 6, 29, 23, 47, 24, 990756)),
#  ('GOSALESDW', 'GO_SATISFACTION_DIM', datetime.datetime(2016, 6, 29, 23, 47, 25, 89485)),
#  ('GOSALESDW', 'GO_TIME_DIM', datetime.datetime(2016, 6, 29, 23, 47, 25, 176011)),
#  ('GOSALESDW', 'GO_TIME_QUARTER_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 25, 273887)),
#  ('GOSALESDW', 'MRK_ACTIVITY_STATUS_DIM', datetime.datetime(2016, 6, 29, 23, 47, 25, 358570)),
#  ('GOSALESDW', 'MRK_ADV_FACT', datetime.datetime(2016, 6, 29, 23, 47, 25, 444193)),
#  ('GOSALESDW', 'MRK_BUNDLE_GROUP_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 25, 523010)),
#  ('GOSALESDW', 'MRK_CAMPAIGN_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 25, 608535)),
#  ('GOSALESDW', 'MRK_PRODUCT_SURVEY_DIM', datetime.datetime(2016, 6, 29, 23, 47, 25, 696892)),
#  ('GOSALESDW', 'MRK_PRODUCT_SURVEY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 25, 783536)),
#  ('GOSALESDW', 'MRK_PROD_SURVEY_TARG_FACT', datetime.datetime(2016, 6, 29, 23, 47, 25, 864200)),
#  ('GOSALESDW', 'MRK_PROMOTION_DIM', datetime.datetime(2016, 6, 29, 23, 47, 25, 944454)),
#  ('GOSALESDW', 'MRK_PROMOTION_FACT', datetime.datetime(2016, 6, 29, 23, 47, 26, 32911)),
#  ('GOSALESDW', 'MRK_PROMOTION_PLAN_FACT', datetime.datetime(2016, 6, 29, 23, 47, 26, 117018)),
#  ('GOSALESDW', 'MRK_RTL_SURVEY_DIM', datetime.datetime(2016, 6, 29, 23, 47, 26, 198629)),
#  ('GOSALESDW', 'MRK_RTL_SURVEY_FACT', datetime.datetime(2016, 6, 29, 23, 47, 26, 289342)),
#  ('SAMPLES ', 'STATECODE', datetime.datetime(2016, 6, 29, 23, 52, 12, 398599)),
#  ('SAMPLES ', 'MILITARY_STATUS', datetime.datetime(2016, 6, 29, 23, 52, 12, 458713)),
#  ('SAMPLES ', 'GEO_COUNTY', datetime.datetime(2016, 6, 30, 0, 3, 2, 266229)),
#  ('SAMPLES ', 'GEO_TORNADO', datetime.datetime(2016, 6, 30, 0, 3, 11, 642101)),
#  ('SAMPLES ', 'GEO_CUSTOMER', datetime.datetime(2016, 6, 30, 0, 3, 19, 550756)),
#  ('SAMPLES ', 'SHOWCASE_SYSTEMS', datetime.datetime(2016, 6, 30, 0, 6, 2, 523068)),
#  ('SAMPLES ', 'SHOWCASE_SYSTYPES', datetime.datetime(2016, 6, 30, 0, 6, 2, 641785)),
#  ('SAMPLES ', 'SHOWCASE_SYSUSAGE', datetime.datetime(2016, 6, 30, 0, 6, 2, 762556)),
#  ('GOSALESDW', 'MRK_RTL_SURVEY_TARG_FACT', datetime.datetime(2016, 6, 29, 23, 47, 26, 369805)),
#  ('GOSALESDW', 'SLS_ORDER_METHOD_DIM', datetime.datetime(2016, 6, 29, 23, 47, 26, 448372)),
#  ('GOSALESDW', 'SLS_PRODUCT_BRAND_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 26, 536182)),
#  ('GOSALESDW', 'SLS_PRODUCT_COLOR_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 26, 620205)),
#  ('GOSALESDW', 'SLS_PRODUCT_DIM', datetime.datetime(2016, 6, 29, 23, 47, 26, 707215)),
#  ('GOSALESDW', 'SLS_PRODUCT_LINE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 26, 785540)),
#  ('GOSALESDW', 'SLS_PRODUCT_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 26, 866604)),
#  ('GOSALESDW', 'SLS_PRODUCT_SIZE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 26, 940080)),
#  ('GOSALESDW', 'SLS_PRODUCT_TYPE_LOOKUP', datetime.datetime(2016, 6, 29, 23, 47, 27, 21679)),
#  ('GOSALESDW', 'SLS_RTL_DIM', datetime.datetime(2016, 6, 29, 23, 47, 27, 103922)),
#  ('GOSALESDW', 'SLS_SALES_FACT', datetime.datetime(2016, 6, 29, 23, 47, 27, 201013)),
#  ('GOSALESDW', 'SLS_SALES_ORDER_DIM', datetime.datetime(2016, 6, 29, 23, 47, 27, 277683)),
#  ('GOSALESDW', 'SLS_SALES_TARG_FACT', datetime.datetime(2016, 6, 29, 23, 47, 27, 349122)),
#  ('GOSALESDW', 'XGOREVDW', datetime.datetime(2016, 6, 29, 23, 47, 27, 422091)),
#  ('GOSALESDW', 'VIEW_ACCOUNT_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 456248)),
#  ('GOSALESDW', 'VIEW_BALANCED_ORG_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 476374)),
#  ('GOSALESDW', 'VIEW_ORG_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 480557)),
#  ('GOSALESDW', 'VIEW_PRODUCT_NAME', datetime.datetime(2016, 6, 29, 23, 50, 13, 486693)),
#  ('GOSALESDW', 'VIEW_STATEMENT_FACT', datetime.datetime(2016, 6, 29, 23, 50, 13, 495016)),
#  ('GOSALESDW', 'VIEW_SUBMISSION_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 510741)),
#  ('GOSALESDW', 'VIEW_TIME_MONTH_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 521459)),
#  ('GOSALESDW', 'VW_ACTIVE_EMPLOYEE_DIM', datetime.datetime(2016, 6, 29, 23, 50, 13, 528036)),
#  ('SAMPLES ', 'CUSTOMER_ACQUISITION', datetime.datetime(2016, 6, 29, 23, 51, 22, 239570)),
#  ('SAMPLES ', 'CUSTOMER_CHURN', datetime.datetime(2016, 6, 29, 23, 51, 22, 401312)),
#  ('SAMPLES ', 'CUST_RETENTION_DEMOGRAPHICS', datetime.datetime(2016, 6, 29, 23, 51, 22, 481240)),
#  ('SAMPLES ', 'CUST_RETENTION_LIFE_DURATION', datetime.datetime(2016, 6, 29, 23, 51, 22, 558985)),
#  ('SAMPLES ', 'CUST_RETENTION_TRANSACTIONS', datetime.datetime(2016, 6, 29, 23, 51, 22, 633164)),
#  ('SAMPLES ', 'CUST_WIN_BACK', datetime.datetime(2016, 6, 29, 23, 51, 22, 706980)),
#  ('SAMPLES ', 'EVAL', datetime.datetime(2016, 6, 29, 23, 51, 22, 781643)),
#  ('SAMPLES ', 'TRAINING', datetime.datetime(2016, 6, 29, 23, 51, 22, 858073)),
#  ('SAMPLES ', 'PERSON', datetime.datetime(2016, 6, 29, 23, 52, 11, 230399)),
#  ('SAMPLES ', 'ANCESTRY', datetime.datetime(2016, 6, 29, 23, 52, 11, 427856)),
#  ('SAMPLES ', 'CITSTATUS', datetime.datetime(2016, 6, 29, 23, 52, 11, 507852)),
#  ('SAMPLES ', 'COW', datetime.datetime(2016, 6, 29, 23, 52, 11, 591251)),
#  ('SAMPLES ', 'EDUCATION', datetime.datetime(2016, 6, 29, 23, 52, 11, 668595)),
#  ('SAMPLES ', 'GENDER', datetime.datetime(2016, 6, 29, 23, 52, 11, 780923)),
#  ('SAMPLES ', 'HISPANIC_ORIGIN', datetime.datetime(2016, 6, 29, 23, 52, 11, 869201)),
#  ('SAMPLES ', 'TRANSPORTATION', datetime.datetime(2016, 6, 29, 23, 52, 11, 957692)),
#  ('SAMPLES ', 'LANGUAGE', datetime.datetime(2016, 6, 29, 23, 52, 12, 45443)),
#  ('SAMPLES ', 'MARITAL_STATUS', datetime.datetime(2016, 6, 29, 23, 52, 12, 104761)),
#  ('SAMPLES ', 'PLACE_OF_BIRTH', datetime.datetime(2016, 6, 29, 23, 52, 12, 157303)),
#  ('SAMPLES ', 'PLACE_OF_WORK', datetime.datetime(2016, 6, 29, 23, 52, 12, 209589)),
#  ('SAMPLES ', 'RACE_CODE', datetime.datetime(2016, 6, 29, 23, 52, 12, 258123)),
#  ('SAMPLES ', 'RACE_CODE2', datetime.datetime(2016, 6, 29, 23, 52, 12, 301403)),
#  ('SAMPLES ', 'RACE_CODE3', datetime.datetime(2016, 6, 29, 23, 52, 12, 346928)),
#  ('DASH101176', 'SCHOOLS', datetime.datetime(2019, 4, 4, 21, 21, 55, 478654))]

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.TABLES contains the table metadata
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA='YOUR-DB2-USERNAME'
#
# or, you can retrieve list of all tables where the schema name is not one of the system created ones:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
#       where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
#
# or, just query for a specifc table that you want to verify exists in the database
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://dash101176:***@dashdb-entry-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB;
# Done.
# [(Decimal('78'),)]

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.COLUMNS contains the column metadata
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://dash101176:***@dashdb-entry-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB;
# Done.
# [('School_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 65),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Street_Address', 'VARCHAR', 30),
#  ('City', 'VARCHAR', 7),
#  ('State', 'VARCHAR', 2),
#  ('ZIP_Code', 'INTEGER', 4),
#  ('Phone_Number', 'VARCHAR', 14),
#  ('Link', 'VARCHAR', 78),
#  ('Network_Manager', 'VARCHAR', 40),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('Ward', 'SMALLINT', 2),
#  ('Police_District', 'SMALLINT', 2),
#  ('Location', 'VARCHAR', 27),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Track_Schedule', 'VARCHAR', 12),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('Safety_Icon', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('Family_Involvement_Icon', 'VARCHAR', 11),
#  ('Family_Involvement_Score', 'VARCHAR', 3),
#  ('Environment_Icon', 'VARCHAR', 11),
#  ('Environment_Score', 'SMALLINT', 2),
#  ('Instruction_Icon', 'VARCHAR', 11),
#  ('Instruction_Score', 'SMALLINT', 2),
#  ('Leaders_Icon', 'VARCHAR', 11),
#  ('Leaders_Score', 'VARCHAR', 3),
#  ('Teachers_Icon', 'VARCHAR', 11),
#  ('Teachers_Score', 'VARCHAR', 3),
#  ('Parent_Engagement_Icon', 'VARCHAR', 7),
#  ('Parent_Engagement_Score', 'VARCHAR', 3),
#  ('Parent_Environment_Icon', 'VARCHAR', 7),
#  ('Parent_Environment_Score', 'VARCHAR', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR', 6),
#  ('Rate_of_Misconducts__per_100_students_', 'DECIMAL', 5),
#  ('Average_Teacher_Attendance', 'VARCHAR', 6),
#  ('Individualized_Education_Program_Compliance_Rate', 'VARCHAR', 7),
#  ('Pk_2_Literacy__', 'VARCHAR', 4),
#  ('Pk_2_Math__', 'VARCHAR', 4),
#  ('Gr3_5_Grade_Level_Math__', 'VARCHAR', 4),
#  ('Gr3_5_Grade_Level_Read__', 'VARCHAR', 4),
#  ('Gr3_5_Keep_Pace_Read__', 'VARCHAR', 4),
#  ('Gr3_5_Keep_Pace_Math__', 'VARCHAR', 4),
#  ('Gr6_8_Grade_Level_Math__', 'VARCHAR', 4),
#  ('Gr6_8_Grade_Level_Read__', 'VARCHAR', 4),
#  ('Gr6_8_Keep_Pace_Math_', 'VARCHAR', 4),
#  ('Gr6_8_Keep_Pace_Read__', 'VARCHAR', 4),
#  ('Gr_8_Explore_Math__', 'VARCHAR', 4),
#  ('Gr_8_Explore_Read__', 'VARCHAR', 4),
#  ('ISAT_Exceeding_Math__', 'DECIMAL', 4),
#  ('ISAT_Exceeding_Reading__', 'DECIMAL', 4),
#  ('ISAT_Value_Add_Math', 'DECIMAL', 3),
#  ('ISAT_Value_Add_Read', 'DECIMAL', 3),
#  ('ISAT_Value_Add_Color_Math', 'VARCHAR', 6),
#  ('ISAT_Value_Add_Color_Read', 'VARCHAR', 6),
#  ('Students_Taking__Algebra__', 'VARCHAR', 4),
#  ('Students_Passing__Algebra__', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR', 4),
#  ('10th Grade PLAN (2009)', 'VARCHAR', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR', 4),
#  ('Net_Change_EXPLORE_and_PLAN', 'VARCHAR', 3),
#  ('11th Grade Average ACT (2011)', 'VARCHAR', 4),
#  ('Net_Change_PLAN_and_ACT', 'VARCHAR', 3),
#  ('College_Eligibility__', 'VARCHAR', 4),
#  ('Graduation_Rate__', 'VARCHAR', 4),
#  ('College_Enrollment_Rate__', 'VARCHAR', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('General_Services_Route', 'SMALLINT', 2),
#  ('Freshman_on_Track_Rate__', 'VARCHAR', 4),
#  ('X_COORDINATE', 'DECIMAL', 13),
#  ('Y_COORDINATE', 'DECIMAL', 13),
#  ('Latitude', 'DECIMAL', 18),
#  ('Longitude', 'DECIMAL', 18)]

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# or
#
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Questions
# 1. Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
# 1. What is the name of "Community Area Name" column in your table? Does it have spaces?
# 1. Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "_"?

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://dash101176:***@dashdb-entry-yp-dal09-10.services.dal.bluemix.net:50000/BLUDB;
# Done.
# [(Decimal('462'),)]

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# Which column specifies the school type e.g. 'ES', 'MS', 'HS'?
# -->

# %% [markdown]
# Double-click __here__ for another hint
#
# <!--
# Does the column name have mixed case, spaces or other special characters?
# If so, ensure you use double quotes around the "Name of the Column"
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES'
#
# Correct answer: 462
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# Use the MAX() function
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
#
# Correct answer: 99
# -->

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
# In the previous problem we found out that the highest Safety Score is 99, so we can use that as an input in the where clause:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where Safety_Score = 99
#
# or, a better way:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where \
#   Safety_Score= (select MAX(Safety_Score) from SCHOOLS)
#
#
# Correct answer: several schools with with Safety Score of 99.
# -->

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
#     order by Average_Student_Attendance desc nulls last limit 10
#
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# Use the REPLACE() function to replace '%' with ''
# See documentation for this function at:
# https://www.ibm.com/support/knowledgecenter/en/SSEPGG_10.5.0/com.ibm.db2.luw.sql.ref.doc/doc/r0000843.html
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# The datatype of the "Average_Student_Attendance" column is varchar.
# So you cannot use it as is in the where clause for a numeric comparison.
# First use the CAST() function to cast it as a DECIMAL or DOUBLE
# e.g. CAST("Column_Name" as DOUBLE)
# or simply: DECIMAL("Column_Name")
# -->

# %% [markdown]
# Double-click __here__ for another hint
#
# <!--
# Don't forget the '%' age sign needs to be removed before casting
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
#      order by Average_Student_Attendance
#
# or,
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where DECIMAL ( REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
#      order by Average_Student_Attendance
#
# -->

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# Verify the exact name of the Enrollment column in the database
# Use the SUM() function to add up the Enrollments for each Community Area
# -->

# %% [markdown]
# Double-click __here__ for another hint
#
# <!--
# Don't forget to group by the Community Area
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name
#
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %% [markdown]
# Double-click __here__ for a hint
#
# <!--
# Order the previous query and limit the number of rows you fetch
# -->

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name \
#    order by TOTAL_ENROLLMENT asc \
#    fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 10
#
# ##### Get the hardship index for the community area which has College Enrollment of 4638

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %%sql
# select hardship_index
#    from chicago_socioeconomic_data CD, schools CPS
#    where CD.ca = CPS.community_area_number
#       and college_enrollment = 4368
#
# -->

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has the highest value for College Enrollment

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
#    where ca in \
#    ( select community_area_number from schools order by college_enrollment desc limit 1 )
#
# -->

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# Copyright &copy; 2018 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
